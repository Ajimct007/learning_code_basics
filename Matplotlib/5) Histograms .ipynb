# %%
'''
Histograms are bar charts where the Y axis contains the frequency of the variable
In histograms, x axis contains a variable and y axis will be a frequency of that variable

'''

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
'''
We have a sample data of blood sugar level of different patients, 
we will try to plot number of patients by blood range and 
try to figure out how many patients are normal, pre-diabetic and diabetic

'''
#we dont need the name of the patients since we will work with frequency of the numbers

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar,bins=3, rwidth=0.95)
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <BarContainer object of 3 artists>)

# %%
#Customise the range using bin parameter
plt.hist(blood_sugar,bins=[80,100,125,150], rwidth=0.95)
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %%
#change the color of the chart
plt.hist(blood_sugar,bins=[80,100,125,150], rwidth=0.95, color='green')
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %%
#for step which shows the wireframe insted of a solid color
plt.hist(blood_sugar,bins=[80,100,125,150], rwidth=0.95, color='green', histtype='step')
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 150.]),
#  [<matplotlib.patches.Polygon at 0x14270d76230>])

# %%
#Mutiple data samples in a histogram
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

#this will give side by side histogram
#we have to add the labels
plt.xlabel('sugar range')
plt.ylabel('Total no of patients')
plt.title('Blood sugar analysis')
plt.hist([blood_sugar_men,blood_sugar_women],bins=[80,100,125,150],rwidth=0.95, color=['green','orange'],
        label=['men','women'])
plt.legend()

# %%
#Mutiple data samples in a histogram
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

#this will give side by side histogram
#we have to add the labels
plt.xlabel('sugar range')
plt.ylabel('Total no of patients')
plt.title('Blood sugar analysis')
plt.hist([blood_sugar_men,blood_sugar_women],bins=[80,100,125,150],rwidth=0.95, color=['green','orange'],
        label=['men','women'],orientation ='horizontal')#for plotting in horizontal manner
plt.legend()
